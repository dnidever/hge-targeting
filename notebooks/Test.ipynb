# %% [markdown]
# ## HGE Targeting Notebook

# %%
import os
import numpy as np
from astropy.table import Table
import matplotlib
import matplotlib.pyplot as plt
from hgetargeting import utils
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 6
#       4 import matplotlib
#       5 import matplotlib.pyplot as plt
# ----> 6 from hgetargeting import utils
#       7 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'hgetargeting'

# %% [markdown]
# # Load some synthetic population catalogs

# %%
datadir = utils.datadir()
syntab = Table.read(datadir+'hge_gums_marshall_l-10.0_b-1.0.fits.gz')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 datadir = utils.datadir()
#       2 syntab = Table.read(datadir+'hge_gums_marshall_l-10.0_b-1.0.fits.gz')
#
# NameError: name 'utils' is not defined
