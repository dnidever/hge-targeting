# %% [markdown]
# ## HGE Targeting Notebook

# %%
import os
import numpy as np
from astropy.table import Table
import matplotlib
import matplotlib.pyplot as plt
from hgetargeting import utils
# %matplotlib inline

# %% [markdown]
# # Load some synthetic population catalogs

# %%
datadir = utils.datadir()
syntab = Table.read(datadir+'hge_gums_marshall_l-10.0_b-1.0.fits.gz')

# %%
syntab
# Out:
# <Table length=2230>
#   pop     iMass      age    Fe/H_initial    Mass    In_Final_Phase    Dist   ... Gaia_RP_EDR3  2MASS_J   2MASS_H   2MASS_Ks  IRAC_3.6  IRAC_4.5
# float64  float64   float64    float64     float64      float64      float64  ...   float64     float64   float64   float64   float64   float64
# ------- ---------- ------- ------------- ---------- -------------- --------- ... ------------ --------- --------- --------- --------- ---------
#     0.0  1.0543636    10.0    0.11265956  1.0535339            0.0 4.6421063 ...    26.333859  18.69391  16.19263 15.130478 14.327117 14.236151
#     0.0  1.0992962    10.0    0.29347439  1.0976046            0.0 5.8709782 ...    23.837093 16.808094   14.4166 13.425008 12.693104 12.659783
#     0.0  1.0305913    10.0   0.014053325  1.0297351            0.0 6.2755277 ...    25.374881 18.732381 16.518775 15.602515 14.910846 14.836865
# ...

# %%
plt.scatter(syntab['l'],syntab['b'])

# %%
fig = plt.figure(figsize=(8,8))
plt.scatter(syntab['2MASS_J']-syntab['2MASS_Ks'],syntab['2MASS_H'])
plt.ylim(19,8)
# Out:
# (19.0, 8.0)
